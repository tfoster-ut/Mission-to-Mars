# %%
# Import Splinter and Beautiful Soup
from splinter import Browser
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
# Sewt executable path and initialize Chrome browser
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
# Visit Mars Nasa Site
url = 'https://mars.nasa.gov/news/'
browser.visit(url)
# Optional delay for loading the page
browser.is_element_not_present_by_css("ul.item_list li.slide", wait_time=3)
# Out:
# False

# %%
# Setup HTML parser
html = browser.html
news_soup = soup(html, 'html.parser')
slide_elem = news_soup.select_one('ul.item_list li.slide')
slide_elem
# Out:
# <li class="slide"><div class="image_and_description_container"><a href="/news/8765/ai-is-helping-scientists-discover-fresh-craters-on-mars/" target="_self"><div class="rollover_description"><div class="rollover_description_inner">It's the first time machine learning has been used to find previously unknown craters on the Red Planet.</div><div class="overlay_arrow"><img alt="More" src="/assets/overlay-arrow.png"/></div></div><div class="list_image"><img alt="crater cluster on Mars" src="/system/news_items/list_view_images/8765_PIA24040-320.jpg"/></div><div class="bottom_gradient"><div><h3>AI Is Helping Scientists Discover Fresh Craters on Mars</h3></div></div></a><div class="list_text"><div class="list_date">October  1, 2020</div><div class="content_title"><a href="/news/8765/ai-is-helping-scientists-discover-fresh-craters-on-mars/" target="_self">AI Is Helping Scientists Discover Fresh Craters on Mars</a></div><div class="article_teaser_body">It's the first time machine learning has been used to find previously unknown craters on the Red Planet.</div></div></div></li>

# %%
# This line of code looks inside the slide.elem and specificall identifies the "div and class"
slide_elem.find("div", class_="content_title")
# Out:
# <div class="content_title"><a href="/news/8765/ai-is-helping-scientists-discover-fresh-craters-on-mars/" target="_self">AI Is Helping Scientists Discover Fresh Craters on Mars</a></div>

# %%
# Use the parent element to find the first `a` tag and save it as `news_title`
news_title = slide_elem.find("div", class_="content_title").get_text()
news_title
# Out:
# 'AI Is Helping Scientists Discover Fresh Craters on Mars'

# %%
# Use the parent element to find the paragraph text
news_p = slide_elem.find("div", class_="article_teaser_body").get_text()
news_p
# Out:
# "It's the first time machine learning has been used to find previously unknown craters on the Red Planet."

# %% [markdown]
# ### Featured Images

# %%
# Visit URL
url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
browser.visit(url)

# %%
# Find and click the full image button
full_image_elem = browser.find_by_id("full_image")
full_image_elem.click()

# %%
# Find the more info button and click that
browser.is_element_present_by_text("more info", wait_time=1)
more_info_elem = browser.links.find_by_partial_text("more info")
more_info_elem.click()

# %%
# Parse the resulting html with soup
html = browser.html
img_soup = soup(html, "html.parser")

# %%
# Find the relative image url
img_url_rel = img_soup.select_one("figure.lede a img").get("src")
img_url_rel
# Out:
# '/spaceimages/images/largesize/PIA15883_hires.jpg'

# %%
# Use the base URL to create an absolute URL
img_url = f'http://www.jpl.nasa.gov{img_url_rel}'
img_url
# Out:
# 'http://www.jpl.nasa.gov/spaceimages/images/largesize/PIA15883_hires.jpg'

# %% [markdown]
# ### Mars Facts

# %%
df = pd.read_html('http://space-facts.com/mars/')[0]
df.columns=['description', 'value']
df.set_index('description', inplace=True)
df
# Out:
#                                               value
# description
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.39 × 10^23 kg (0.11 Earths)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.38 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                   -87 to -5 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>value</th>\n    </tr>\n    <tr>\n      <th>description</th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Equatorial Diameter:</th>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <th>Polar Diameter:</th>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <th>Mass:</th>\n      <td>6.39 × 10^23 kg (0.11 Earths)</td>\n    </tr>\n    <tr>\n      <th>Moons:</th>\n      <td>2 (Phobos &amp; Deimos)</td>\n    </tr>\n    <tr>\n      <th>Orbit Distance:</th>\n      <td>227,943,824 km (1.38 AU)</td>\n    </tr>\n    <tr>\n      <th>Orbit Period:</th>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <th>Surface Temperature:</th>\n      <td>-87 to -5 °C</td>\n    </tr>\n    <tr>\n      <th>First Record:</th>\n      <td>2nd millennium BC</td>\n    </tr>\n    <tr>\n      <th>Recorded By:</th>\n      <td>Egyptian astronomers</td>\n    </tr>\n  </tbody>\n</table>'

# %% [markdown]
# ### Mars Weather

# %%
# Visit the weather website
url = 'https://mars.nasa.gov/insight/weather/'
browser.visit(url)

# %%
# Parse the data
html = browser.html
weather_soup = soup(html, 'html.parser')

# %%
# Scrape the Daily Weather Report table
weather_table = weather_soup.find('table', class_='mb_table')
print(weather_table.prettify())
# Out:
# <table class="mb_table" id="weather_observation" style="width:100%;">
#  <thead>
#   <tr>
#    <th colspan="2" scope="col">
#     Time
#    </th>
#    <th colspan="3" id="temperature_lbl" scope="col">
#     Air Temperature (
#     <span class="lbl_fahrenheit">
#      °F
#     </span>
#     <span class="slash">
#      |
#     </span>
#     <span class="lbl_celsius fadeBlack">
#      °C
#     </span>
#     )
#    </th>
#    <th colspan="4" id="windspeed_lbl" scope="col">
#     Wind Speed (
#     <span class="lbl_mph">
#      mph
#     </span>
#     <span class="slash">
#      |
#     </span>
#     <span class="lbl_mps fadeBlack">
#      m/s
#     </span>
#     )
#    </th>
#    <th colspan="3" id="pressure_lbl" scope="col">
#     Pressure (Pa)
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr id="weather_top">
#    <th class="sol" scope="row">
#     Date
#    </th>
#    <th class="sol" scope="row">
#     Sol
#    </th>
#    <td class="temperature max">
#     Max.
#    </td>
#    <td class="temperature avg">
#     Avg.
#    </td>
#    <td class="temperature min">
#     Min.
#    </td>
#    <td class="windspeed max">
#     Max.
#    </td>
#    <td class="windspeed avg">
#     Avg.
#    </td>
#    <td class="windspeed min">
#     Min.
#    </td>
#    <td class="windspeed direction">
#     Direction
#     <br/>
#     <span style="font-size:x-small">
#      (most common)
#     </span>
#    </td>
#    <td class="pressure max">
#     Max.
#    </td>
#    <td class="pressure avg">
#     Avg.
#    </td>
#    <td class="pressure min">
#     Min.
#    </td>
#   </tr>
#   <tr>
#    <th class="sol" scope="row">
#     Oct. 1, 2020
#    </th>
#    <th class="sol" scope="row">
#     657
#    </th>
#    <td class="temperature max">
#     <span class="fahrenheit">
#      <nobr>
#       -0.3° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -18° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature avg">
#     <span class="fahrenheit">
#      <nobr>
#       -92.8° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -69.3° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature min">
#     <span class="fahrenheit">
#      <nobr>
#       -142.9° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -97.2° C
#      </nobr>
#     </span>
#    </td>
#    <td class="windspeed max">
#     <span class="mph">
#      51.7
#     </span>
#     <span class="mps" style="display:none">
#      23.1
#     </span>
#    </td>
#    <td class="windspeed avg">
#     <span class="mph">
#      17.9
#     </span>
#     <span class="mps" style="display:none">
#      8
#     </span>
#    </td>
#    <td class="windspeed min">
#     <span class="mph">
#      1.2
#     </span>
#     <span class="mps" style="display:none">
#      0.5
#     </span>
#    </td>
#    <td class="windspeed point">
#     WNW
#    </td>
#    <td class="pressure max">
#     780
#    </td>
#    <td class="pressure avg">
#     763.6
#    </td>
#    <td class="pressure min">
#     732
#    </td>
#   </tr>
#   <tr>
#    <th class="sol" scope="row">
#     Sep. 30, 2020
#    </th>
#    <th class="sol" scope="row">
#     656
#    </th>
#    <td class="temperature max">
#     <span class="fahrenheit">
#      <nobr>
#       -3.3° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -19.6° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature avg">
#     <span class="fahrenheit">
#      <nobr>
#       -83.1° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -63.9° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature min">
#     <span class="fahrenheit">
#      <nobr>
#       -143.1° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -97.3° C
#      </nobr>
#     </span>
#    </td>
#    <td class="windspeed max">
#     <span class="mph">
#      49
#     </span>
#     <span class="mps" style="display:none">
#      21.9
#     </span>
#    </td>
#    <td class="windspeed avg">
#     <span class="mph">
#      19.2
#     </span>
#     <span class="mps" style="display:none">
#      8.6
#     </span>
#    </td>
#    <td class="windspeed min">
#     <span class="mph">
#      2.4
#     </span>
#     <span class="mps" style="display:none">
#      1.1
#     </span>
#    </td>
#    <td class="windspeed point">
#     WNW
#    </td>
#    <td class="pressure max">
#     783
#    </td>
#    <td class="pressure avg">
#     765.1
#    </td>
#    <td class="pressure min">
#     735.9
#    </td>
#   </tr>
#   <tr>
#    <th class="sol" scope="row">
#     Sep. 29, 2020
#    </th>
#    <th class="sol" scope="row">
#     655
#    </th>
#    <td class="temperature max">
#     <span class="fahrenheit">
#      <nobr>
#       -0.3° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -18° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature avg">
#     <span class="fahrenheit">
#      <nobr>
#       -82.2° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -63.5° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature min">
#     <span class="fahrenheit">
#      <nobr>
#       -139.5° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -95.3° C
#      </nobr>
#     </span>
#    </td>
#    <td class="windspeed max">
#     <span class="mph">
#      47.4
#     </span>
#     <span class="mps" style="display:none">
#      21.2
#     </span>
#    </td>
#    <td class="windspeed avg">
#     <span class="mph">
#      19.3
#     </span>
#     <span class="mps" style="display:none">
#      8.6
#     </span>
#    </td>
#    <td class="windspeed min">
#     <span class="mph">
#      3.4
#     </span>
#     <span class="mps" style="display:none">
#      1.5
#     </span>
#    </td>
#    <td class="windspeed point">
#     WNW
#    </td>
#    <td class="pressure max">
#     783.3
#    </td>
#    <td class="pressure avg">
#     766.1
#    </td>
#    <td class="pressure min">
#     734.2
#    </td>
#   </tr>
#   <tr>
#    <th class="sol" scope="row">
#     Sep. 28, 2020
#    </th>
#    <th class="sol" scope="row">
#     654
#    </th>
#    <td class="temperature max">
#     <span class="fahrenheit">
#      <nobr>
#       4° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -15.5° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature avg">
#     <span class="fahrenheit">
#      <nobr>
#       -81.3° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -62.9° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature min">
#     <span class="fahrenheit">
#      <nobr>
#       -140.5° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -95.8° C
#      </nobr>
#     </span>
#    </td>
#    <td class="windspeed max">
#     <span class="mph">
#      46.4
#     </span>
#     <span class="mps" style="display:none">
#      20.8
#     </span>
#    </td>
#    <td class="windspeed avg">
#     <span class="mph">
#      15.2
#     </span>
#     <span class="mps" style="display:none">
#      6.8
#     </span>
#    </td>
#    <td class="windspeed min">
#     <span class="mph">
#      1.7
#     </span>
#     <span class="mps" style="display:none">
#      0.8
#     </span>
#    </td>
#    <td class="windspeed point">
#     WNW
#    </td>
#    <td class="pressure max">
#     779.4
#    </td>
#    <td class="pressure avg">
#     763.2
#    </td>
#    <td class="pressure min">
#     735.7
#    </td>
#   </tr>
#   <tr>
#    <th class="sol" scope="row">
#     Sep. 27, 2020
#    </th>
#    <th class="sol" scope="row">
#     653
#    </th>
#    <td class="temperature max">
#     <span class="fahrenheit">
#      <nobr>
#       13° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -10.6° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature avg">
#     <span class="fahrenheit">
#      <nobr>
#       -90.9° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -68.3° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature min">
#     <span class="fahrenheit">
#      <nobr>
#       -141.3° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -96.3° C
#      </nobr>
#     </span>
#    </td>
#    <td class="windspeed max">
#     <span class="mph">
#      40.2
#     </span>
#     <span class="mps" style="display:none">
#      18
#     </span>
#    </td>
#    <td class="windspeed avg">
#     <span class="mph">
#      13.3
#     </span>
#     <span class="mps" style="display:none">
#      6
#     </span>
#    </td>
#    <td class="windspeed min">
#     <span class="mph">
#      0.5
#     </span>
#     <span class="mps" style="display:none">
#      0.2
#     </span>
#    </td>
#    <td class="windspeed point">
#     W
#    </td>
#    <td class="pressure max">
#     780.8
#    </td>
#    <td class="pressure avg">
#     763.7
#    </td>
#    <td class="pressure min">
#     735.6
#    </td>
#   </tr>
#   <tr>
#    <th class="sol" scope="row">
#     Sep. 26, 2020
#    </th>
#    <th class="sol" scope="row">
#     652
#    </th>
#    <td class="temperature max">
#     <span class="fahrenheit">
#      <nobr>
#       4° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -15.6° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature avg">
#     <span class="fahrenheit">
#      <nobr>
#       -82.1° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -63.4° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature min">
#     <span class="fahrenheit">
#      <nobr>
#       -141° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -96.1° C
#      </nobr>
#     </span>
#    </td>
#    <td class="windspeed max">
#     <span class="mph">
#      41.6
#     </span>
#     <span class="mps" style="display:none">
#      18.6
#     </span>
#    </td>
#    <td class="windspeed avg">
#     <span class="mph">
#      14.3
#     </span>
#     <span class="mps" style="display:none">
#      6.4
#     </span>
#    </td>
#    <td class="windspeed min">
#     <span class="mph">
#      0.6
#     </span>
#     <span class="mps" style="display:none">
#      0.3
#     </span>
#    </td>
#    <td class="windspeed point">
#     WNW
#    </td>
#    <td class="pressure max">
#     779.1
#    </td>
#    <td class="pressure avg">
#     762.2
#    </td>
#    <td class="pressure min">
#     734.8
#    </td>
#   </tr>
#   <tr>
#    <th class="sol" scope="row">
#     Sep. 25, 2020
#    </th>
#    <th class="sol" scope="row">
#     651
#    </th>
#    <td class="temperature max">
#     <span class="fahrenheit">
#      <nobr>
#       3.4° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -15.9° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature avg">
#     <span class="fahrenheit">
#      <nobr>
#       -79.5° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -62° C
#      </nobr>
#     </span>
#    </td>
#    <td class="temperature min">
#     <span class="fahrenheit">
#      <nobr>
#       -142.1° F
#      </nobr>
#     </span>
#     <span class="celsius" style="display: none;">
#      <nobr>
#       -96.7° C
#      </nobr>
#     </span>
#    </td>
#    <td class="windspeed max">
#     <span class="mph">
#      45.3
#     </span>
#     <span class="mps" style="display:none">
#      20.3
#     </span>
#    </td>
#    <td class="windspeed avg">
#     <span class="mph">
#      15.7
#     </span>
#     <span class="mps" style="display:none">
#      7
#     </span>
#    </td>
#    <td class="windspeed min">
#     <span class="mph">
#      0.6
#     </span>
#     <span class="mps" style="display:none">
#      0.2
#     </span>
#    </td>
#    <td class="windspeed point">
#     WNW
#    </td>
#    <td class="pressure max">
#     781.5
#    </td>
#    <td class="pressure avg">
#     764.7
#    </td>
#    <td class="pressure min">
#     736.8
#    </td>
#   </tr>
#  </tbody>
# </table>

# %% [markdown]
# # D1: Scrape High-Resolution Mars’ Hemisphere Images and Titles

# %% [markdown]
# ### Hemispheres

# %%
# 1. Use browser to visit the URL 
url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
browser.visit(url)

# %%
html = browser.html
href = soup(html, 'html.parser')
find_button = browser.links.find_by_partial_text("/search/map/Mars")

# %%
help(browser)
# Out:
# Help on WebDriver in module splinter.driver.webdriver.chrome object:
#
# class WebDriver(splinter.driver.webdriver.BaseWebDriver)
#  |  WebDriver(options=None, user_agent=None, wait_time=2, fullscreen=False, incognito=False, headless=False, **kwargs)
#  |
#  |  Basic driver API class.
#  |
#  |  Method resolution order:
#  |      WebDriver
#  |      splinter.driver.webdriver.BaseWebDriver
#  |      splinter.driver.DriverAPI
#  |      splinter.meta._DriverAPI
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, options=None, user_agent=None, wait_time=2, fullscreen=False, incognito=False, headless=False, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  driver_name = 'Chrome'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from splinter.driver.webdriver.BaseWebDriver:
#  |
#  |  __enter__(self)
#  |      Context manager to use the browser safely.
#  |
#  |  __exit__(self, exc_type, exc_value, traceback)
#  |      Context manager to use the browser safely.
#  |
#  |  attach_file = fill(self, name, value)
#  |
#  |  back(self)
#  |      Back to the last URL in the browsing history.
#  |
#  |      If there is no URL to back, this method does nothing.
#  |
#  |  check(self, name)
#  |      Checks a checkbox by its name.
#  |
#  |      Example:
#  |
#  |          >>> browser.check("agree-with-terms")
#  |
#  |      If you call ``browser.check`` n times, the checkbox keeps checked, it never get unchecked.
#  |
#  |      To unckech a checkbox, take a look in the :meth:`uncheck <DriverAPI.uncheck>` method.
#  |
#  |  choose(self, name, value)
#  |      Chooses a value in a radio buttons group.
#  |
#  |      Suppose you have the two radio buttons in a page, with the name ``gender`` and values 'F' and 'M'.
#  |      If you use the ``choose`` method the following way:
#  |
#  |          >>> browser.choose('gender', 'F')
#  |
#  |      Then you're choosing the female gender.
#  |
#  |  evaluate_script(self, script, *args)
#  |      Similar to :meth:`execute_script <DriverAPI.execute_script>` method.
#  |
#  |      Executes javascript in the browser and returns the value of the expression.
#  |
#  |      e.g.: ::
#  |          >>> assert 4 == browser.evaluate_script('2 + 2')
#  |
#  |  execute_script(self, script, *args)
#  |      Executes a given JavaScript in the browser.
#  |
#  |      e.g.: ::
#  |          >>> browser.execute_script('document.getElementById("body").innerHTML = "<p>Hello world!</p>"')
#  |
#  |  fill(self, name, value)
#  |      Fill the field identified by ``name`` with the content specified by ``value``.
#  |
#  |  fill_form(self, field_values, form_id=None, name=None)
#  |      Fill the fields identified by ``name`` with the content specified by ``value`` in a dict.
#  |
#  |      Currently, fill_form supports the following fields: text, password, textarea, checkbox,
#  |      radio and select.
#  |
#  |      Checkboxes should be specified as a boolean in the dict.
#  |
#  |  find_by(self, finder, selector, original_find=None, original_query=None, wait_time=None)
#  |      Wrapper for finding elements.
#  |
#  |      Must be attached to a class.
#  |
#  |      Returns:
#  |          ElementList
#  |
#  |  find_by_css(self, css_selector, wait_time=None)
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`,
#  |      using a CSS selector to query the current page content.
#  |
#  |  find_by_id(self, id, wait_time=None)
#  |      Finds an element in current page by its id.
#  |
#  |      Even when only one element is find, this method returns an instance of
#  |      :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_by_name(self, name, wait_time=None)
#  |      Finds elements in current page by their name.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`.
#  |
#  |  find_by_tag(self, tag, wait_time=None)
#  |      Find all elements of a given tag in current page.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_by_text(self, text=None, wait_time=None)
#  |      Finds elements in current page by their text.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_by_value(self, value, wait_time=None)
#  |      Finds elements in current page by their value.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_by_xpath(self, xpath, original_find=None, original_query=None, wait_time=None)
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`,
#  |      using a xpath selector to query the current page content.
#  |
#  |  find_link_by_href(self, href)
#  |      Find all elements of a given tag in current page.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_link_by_partial_href(self, partial_href)
#  |      Find links by looking for a partial ``str`` in their href attribute.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_link_by_partial_text(self, partial_text)
#  |      Find links by looking for a partial ``str`` in their text.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_link_by_text(self, text)
#  |      Find links querying for their text.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_option_by_text(self, text)
#  |      Finds ``<option>`` elements by their text.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  find_option_by_value(self, value)
#  |      Finds ``<option>`` elements by their value.
#  |
#  |      Returns an instance of :class:`ElementList <splinter.element_list.ElementList>`
#  |
#  |  forward(self)
#  |      Forward to the next URL in the browsing history.
#  |
#  |      If there is no URL to forward, this method does nothing.
#  |
#  |  full_screen(self)
#  |
#  |  get_alert(self, wait_time=None)
#  |      Changes the context for working with alerts and prompts.
#  |
#  |      For more details, check the :doc:`docs about iframes, alerts and prompts </iframes-and-alerts>`
#  |
#  |  get_iframe(self, frame_reference)
#  |      Changes the context for working with iframes.
#  |
#  |      For more details, check the :doc:`docs about iframes, alerts and prompts </iframes-and-alerts>`
#  |
#  |  html_snapshot(self, name='', suffix='.html', encoding='utf-8')
#  |      Write the current html to a file.
#  |
#  |  is_element_not_present(self, finder, selector, wait_time=None)
#  |
#  |  is_element_not_present_by_css(self, css_selector, wait_time=None)
#  |      Verify if the element is not present in the current page by css, and wait the specified time
#  |      in ``wait_time``.
#  |
#  |      Returns True if the element is not present and False if is present.
#  |
#  |  is_element_not_present_by_id(self, id, wait_time=None)
#  |      Verify if the element is present in the current page by id,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is not present and False if is present.
#  |
#  |  is_element_not_present_by_name(self, name, wait_time=None)
#  |      Verify if the element is not present in the current page by name,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is not present and False if is present.
#  |
#  |  is_element_not_present_by_tag(self, tag, wait_time=None)
#  |      Verify if the element is not present in the current page by tag,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is not present and False if is present.
#  |
#  |  is_element_not_present_by_text(self, text, wait_time=None)
#  |      Verify if the element is not present in the current page by text,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is not present and False if is present.
#  |
#  |  is_element_not_present_by_value(self, value, wait_time=None)
#  |      Verify if the element is not present in the current page by value,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is not present and False if is present.
#  |
#  |  is_element_not_present_by_xpath(self, xpath, wait_time=None)
#  |      Verify if the element is not present in the current page by xpath,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is not present and False if is present.
#  |
#  |  is_element_not_visible(self, finder, selector, wait_time=None)
#  |
#  |  is_element_not_visible_by_css(self, css_selector, wait_time=None)
#  |
#  |  is_element_not_visible_by_xpath(self, xpath, wait_time=None)
#  |
#  |  is_element_present(self, finder, selector, wait_time=None)
#  |
#  |  is_element_present_by_css(self, css_selector, wait_time=None)
#  |      Verify if the element is present in the current page by css, and wait the specified
#  |      time in ``wait_time``.
#  |
#  |      Returns True if the element is present and False if is not present.
#  |
#  |  is_element_present_by_id(self, id, wait_time=None)
#  |      Verify if the element is present in the current page by id,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is present and False if is not present.
#  |
#  |  is_element_present_by_name(self, name, wait_time=None)
#  |      Verify if the element is present in the current page by name,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is present and False if is not present.
#  |
#  |  is_element_present_by_tag(self, tag, wait_time=None)
#  |      Verify if the element is present in the current page by tag,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is present and False if is not present.
#  |
#  |  is_element_present_by_text(self, text, wait_time=None)
#  |      Verify if the element is present in the current page by text,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is present and False if is not present.
#  |
#  |  is_element_present_by_value(self, value, wait_time=None)
#  |      Verify if the element is present in the current page by value,
#  |      and wait the specified time in ``wait_time``.
#  |
#  |      Returns True if the element is present and False if is not present.
#  |
#  |  is_element_present_by_xpath(self, xpath, wait_time=None)
#  |      Verify if the element is present in the current page by xpath, and wait the specified
#  |      time in ``wait_time``.
#  |
#  |      Returns True if the element is present and False if is not present.
#  |
#  |  is_element_visible(self, finder, selector, wait_time=None)
#  |
#  |  is_element_visible_by_css(self, css_selector, wait_time=None)
#  |
#  |  is_element_visible_by_xpath(self, xpath, wait_time=None)
#  |
#  |  is_text_not_present(self, text, wait_time=None)
#  |
#  |  is_text_present(self, text, wait_time=None)
#  |      Searchs for ``text`` in the browser and wait the seconds specified in ``wait_time``.
#  |
#  |      Returns True if finds a match for the ``text`` and False if not.
#  |
#  |  quit(self)
#  |      Quits the browser, closing its windows (if it has one).
#  |
#  |      After quit the browser, you can't use it anymore.
#  |
#  |  recover_screen(self, size)
#  |
#  |  reload(self)
#  |      Revisits the current URL
#  |
#  |  screenshot(self, name='', suffix='.png', full=False)
#  |      Takes a screenshot of the current page and saves it locally.
#  |
#  |  select(self, name, value)
#  |      Selects an ``<option>`` element in an ``<select>`` element using the ``name`` of the ``<select>`` and
#  |      the ``value`` of the ``<option>``.
#  |
#  |      Example:
#  |
#  |          >>> browser.select("state", "NY")
#  |
#  |  select_by_text(self, name, text)
#  |
#  |  type(self, name, value, slowly=False)
#  |      Types the ``value`` in the field identified by ``name``.
#  |
#  |      It's useful to test javascript events like keyPress, keyUp, keyDown, etc.
#  |
#  |      If ``slowly`` is True, this function returns an iterator which will type one character per iteration.
#  |
#  |  uncheck(self, name)
#  |      Unchecks a checkbox by its name.
#  |
#  |      Example:
#  |
#  |          >>> browser.uncheck("send-me-emails")
#  |
#  |      If you call ``brower.uncheck`` n times, the checkbox keeps unchecked, it never get checked.
#  |
#  |      To check a checkbox, take a look in the :meth:`check <DriverAPI.check>` method.
#  |
#  |  visit(self, url)
#  |      Visits a given URL.
#  |
#  |      The ``url`` parameter is a string.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from splinter.driver.webdriver.BaseWebDriver:
#  |
#  |  cookies
#  |      A :class:`CookieManager <splinter.cookie_manager.CookieManagerAPI>` instance.
#  |
#  |      For more details, check the :doc:`cookies manipulation section </cookies>`.
#  |
#  |  html
#  |      Source of current page.
#  |
#  |  status_code
#  |
#  |  title
#  |      Title of current page.
#  |
#  |  url
#  |      URL of current page.
#  |
#  |  windows
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from splinter.driver.webdriver.BaseWebDriver:
#  |
#  |  driver = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from splinter.driver.DriverAPI:
#  |
#  |  click_link_by_href(self, href)
#  |      Clicks in a link by its ``href`` attribute.
#  |
#  |  click_link_by_id(self, id)
#  |      Clicks in a link by id.
#  |
#  |  click_link_by_partial_href(self, partial_href)
#  |      Clicks in a link by looking for partial content of ``href`` attribute.
#  |
#  |  click_link_by_partial_text(self, partial_text)
#  |      Clicks in a link by partial content of its text.
#  |
#  |  click_link_by_text(self, text)
#  |      Clicks in a link by its ``text``.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from splinter.meta._DriverAPI:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# 2. Create a list to hold the images and titles.

# 3. Write code to retrieve the image urls and titles for each hemisphere.
ce_click = browser.links.find_by_partial_text("Cerberus")
ce_click.click()

html = browser.html
ce_img = soup(html, 'html.parser')
ce_img_link = ce_img.find("div", class_="wide-image-wrapper")
ce_img_link = ce_img_link.find_all("a")[0].get("href")
ce_img_title = ce_img.title.get_text()
browser.back()

sc_click = browser.links.find_by_partial_text("Schiaparelli")
sc_click.click()

html = browser.html
sc_img = soup(html, 'html.parser')
sc_img_link = sc_img.find("div", class_="wide-image-wrapper")
sc_img_link = sc_img_link.find_all("a")[0].get("href")
sc_img_title = sc_img.title.get_text()
browser.back()

sy_click = browser.links.find_by_partial_text("Syrtis")
sy_click.click()

html = browser.html
sy_img = soup(html, 'html.parser')
sy_img_link = sy_img.find("div", class_="wide-image-wrapper")
sy_img_link = sy_img_link.find_all("a")[0].get("href")
sy_img_title = sy_img.title.get_text()
browser.back()

va_click = browser.links.find_by_partial_text("Valles")
va_click.click()

html = browser.html
va_img = soup(html, 'html.parser')
va_img_link = va_img.find("div", class_="wide-image-wrapper")
va_img_link = va_img_link.find_all("a")[0].get("href")
va_img_title = va_img.title.get_text()

hemisphere_image_urls = [{
    ce_img_title: ce_img_link,
    sc_img_title: sc_img_link,
    sy_img_title: sy_img_link,
    va_img_title: va_img_link
}]

# %%
hemisphere_image_urls
# Out:
# [{'Cerberus Hemisphere Enhanced | USGS Astrogeology Science Center': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg',
#   'Schiaparelli Hemisphere Enhanced | USGS Astrogeology Science Center': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg',
#   'Syrtis Major Hemisphere Enhanced | USGS Astrogeology Science Center': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg',
#   'Valles Marineris Hemisphere Enhanced | USGS Astrogeology Science Center': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}]

# %%
html = browser.html
ce_img = soup(html, 'html.parser')
ce_img_link = ce_img.find("div", class_="wide-image-wrapper")
ce_img_link = ce_img_link.find_all("a")[0].get("href")
ce_img_title = ce_img.title.get_text()

# %%
# 4. Print the list that holds the dictionary of each image url and title.
hemisphere_image_urls

# %%
# 5. Quit the browser
browser.quit()
